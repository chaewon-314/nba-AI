# %%
stat=input('예측하려는 능력치를 입력하세요.(age,gp,w,l,min,pts,fgm,fga,fg%,3pm,3pa,3p%,ftm,fta,ft%,oreb,dreb,reb,ast,tov,stl,blk,pf,fp,dd2,td3)')
import pandas as pd
import numpy as np
Allnba=pd.read_csv('NBA stats 종합 csv파일.csv')
Allnba.head()
age=Allnba['AGE'].to_numpy()          #엑셀 파일의 각 행을 numpy 배열로 하나씩 변환
gp=Allnba['GP'].to_numpy()
w=Allnba['W'].to_numpy()
l=Allnba['L'].to_numpy()
min=Allnba['MIN'].to_numpy()
pts=Allnba['PTS'].to_numpy()
fgm=Allnba['FGM'].to_numpy()
fga=Allnba['FGA'].to_numpy()
fg_=Allnba['FG%'].to_numpy()
_3pm=Allnba['3PM'].to_numpy()
_3pa=Allnba['3PA'].to_numpy()
_3p_=Allnba['3P%'].to_numpy()
ftm=Allnba['FTM'].to_numpy()
fta=Allnba['FTA'].to_numpy()
ft_=Allnba['FT%'].to_numpy()
oreb=Allnba['OREB'].to_numpy()
dreb=Allnba['DREB'].to_numpy()
reb=Allnba['REB'].to_numpy()
ast=Allnba['AST'].to_numpy()
tov=Allnba['TOV'].to_numpy()
stl=Allnba['STL'].to_numpy()
blk=Allnba['BLK'].to_numpy()
pf=Allnba['PF'].to_numpy()
fp=Allnba['FP'].to_numpy()
dd2=Allnba['DD2'].to_numpy()
td3=Allnba['TD3'].to_numpy()


delete_index=100           #타깃 변수를 학습 데이터에서 제외하기 위해 타깃 변수의 인덱스 설정
if stat == 'age':
  delete_index=0
if stat == 'gp':
  delete_index=1
if stat == 'w':
  delete_index=2
if stat == 'l':
  delete_index=3
if stat == 'min':
  delete_index=4
if stat == 'pts':
  delete_index=5
if stat == 'fgm':
  delete_index=6
if stat == 'fga':
  delete_index=7
if stat == 'fg%':
  delete_index=8
if stat == '3pm':
  delete_index=9
if stat == '3pa':
  delete_index=10
if stat == '3p%':
  delete_index=11
if stat == 'ftm':
  delete_index=12
if stat == 'fta':
  delete_index=13
if stat == 'ft%':
  delete_index=14
if stat == 'oreb':
  delete_index=15
if stat == 'dreb':
  delete_index=16
if stat == 'reb':
  delete_index=17
if stat == 'ast':
  delete_index=18
if stat == 'tov':
  delete_index=19
if stat == 'stl':
  delete_index=20
if stat == 'blk':
  delete_index=21
if stat == 'pf':
  delete_index=22
if stat == 'fp':
  delete_index=23
if stat == 'dd2':
  delete_index=24
if stat == 'td3':
  delete_index=25

from sklearn.model_selection import train_test_split
input_2D_beforeDelete=np.c_[age,gp,w,l,min,pts,fgm,fga,fg_,_3pm,_3pa,_3p_,ftm,fta,ft_,oreb,dreb,reb,ast,tov,stl,blk,pf,fp,dd2,td3]       #하나의 2차원 배열로 생성하여 모델 입력변수로 사용

input_2D_afterDelete = np.delete(input_2D_beforeDelete, delete_index , axis = 1)


if stat == 'age':             #입력된 타깃 변수별로 _target 변수에 생성하여 데이터 생성
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,age,random_state=42)
if stat == 'gp':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,gp,random_state=42)
if stat == 'w':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,w,random_state=42)
if stat == 'l':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,l,random_state=42)
if stat == 'min':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,min,random_state=42)
if stat == 'pts':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,pts,random_state=42)
if stat == 'fgm':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,fgm,random_state=42)
if stat == 'fga':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,fga,random_state=42)
if stat == 'fg%':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,fg_,random_state=42)
if stat == '3pm':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,_3pm,random_state=42)
if stat == '3pa':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,_3pa,random_state=42)
if stat == '3p%':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,_3p_,random_state=42)
if stat == 'ftm':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,ftm,random_state=42)
if stat == 'fta':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,fta,random_state=42)
if stat == 'ft%':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,ft_,random_state=42)
if stat == 'oreb':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,oreb,random_state=42)
if stat == 'dreb':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,dreb,random_state=42)
if stat == 'reb':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,reb,random_state=42)
if stat == 'ast':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,ast,random_state=42)
if stat == 'tov':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,tov,random_state=42)
if stat == 'stl':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,stl,random_state=42)
if stat == 'blk':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,blk,random_state=42)
if stat == 'pf':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,pf,random_state=42)
if stat == 'fp':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,fp,random_state=42)
if stat == 'dd2':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,dd2,random_state=42)
if stat == 'td3':
  train_input, test_input, train_target,test_target=train_test_split(input_2D_afterDelete,td3,random_state=42)


from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(train_input,train_target)
print(lr.score(train_input,train_target))
print(lr.score(test_input,test_target))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 Allnba=pd.read_csv('NBA stats 종합 csv파일.csv')
#       5 Allnba.head()
#       6 age=Allnba['AGE'].to_numpy()          #엑셀 파일의 각 행을 numpy 배열로 하나씩 변환
#
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D




predict_result = lr.predict(test_input)       #test_input을 입력하여 예측한 값 저장
xAxis_test = test_input[:, 1]     #test_input 에서 인덱스가 1 --> 제 2열의 값들
yAxis_test = test_input[:, 2]     #test_input 에서 인덱스가 2 --> 제 3열의 값들
zAxis_input = test_target


fig = plt.figure(figsize=(10, 10))         #그래프 전체 크기 설정
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xAxis_test, yAxis_test, zAxis_input, c='blue', marker='d', label='training data',s=30)
ax.scatter(xAxis_test, yAxis_test, predict_result, c='red', marker='x', label='predict_result',s=60)
ax.set_xlabel('wins')
ax.set_ylabel('goal point')
ax.set_zlabel('predict')
ax.legend()         #설명 표시
ax.view_init(elev=25, azim=70)        #시점 전환
plt.show()

# %%
#

# %%
import pandas as pd
import numpy as np

Allnba=pd.read_csv('NBA stats 종합 csv파일.csv')
Allnba.head()

reb=Allnba['REB'].to_numpy()
blk=Allnba['BLK'].to_numpy()
#height=Allnba['HGH'].to_numpy()
age=Allnba['AGE'].to_numpy()
gp=Allnba['GP'].to_numpy()
w=Allnba['W'].to_numpy()
l=Allnba['L'].to_numpy()
min=Allnba['MIN'].to_numpy()
pts=Allnba['PTS'].to_numpy()
fgm=Allnba['FGM'].to_numpy()
fga=Allnba['FGA'].to_numpy()
fg_=Allnba['FG%'].to_numpy()
_3pm=Allnba['3PM'].to_numpy()
_3pa=Allnba['3PA'].to_numpy()
_3p_=Allnba['3P%'].to_numpy()
ftm=Allnba['FTM'].to_numpy()
fta=Allnba['FTA'].to_numpy()
ft_=Allnba['FT%'].to_numpy()
oreb=Allnba['OREB'].to_numpy()
dreb=Allnba['DREB'].to_numpy()
ast=Allnba['AST'].to_numpy()
tov=Allnba['TOV'].to_numpy()
stl=Allnba['STL'].to_numpy()
pf=Allnba['PF'].to_numpy()
fp=Allnba['FP'].to_numpy()
dd2=Allnba['DD2'].to_numpy()
td3=Allnba['TD3'].to_numpy()

#print(rebound)
#print(block)
#print(height)


from sklearn.model_selection import train_test_split
input_2D=np.c_[gp,w,l,min,pts,fgm,fga,fg_,_3pm,_3pa,_3p_,ftm,fta,ft_,oreb,dreb,reb,ast,tov,stl,blk,pf,fp,dd2,td3]        #rebound, block를 하나의 2차원 배열로 생성하여 모델 입력변수로 사용
train_input, test_input, train_target,test_target=train_test_split(input_2D,age,random_state=42)
#print(train_input)
#print(train_target)

from sklearn.linear_model import LinearRegression
lr=LinearRegression()

lr.fit(train_input,train_target)

#print(lr.predict([[5.8,10.2]]))

print(lr.score(train_input,train_target))
print(lr.score(test_input,test_target))
# Out:
# 0.155193363894515
# 0.15387284547515412
